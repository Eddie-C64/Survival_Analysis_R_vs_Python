# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

draft_df = pd.read_csv("data/raw_data/pfr_nfl_draft_data_RAW.csv")

# set some plotting aesthetics, similar to ggplot
sns.set(palette = "colorblind", font_scale = 1.35, 
        rc = {"figure.figsize": (12,9), "axes.facecolor": ".92"})

# %%
draft_df.head()
# Out:
#    Draft_Yr  Rnd  Pick   Tm          Player Pos   Age      To  AP1  PB  \
# 0      1967    1     1  BAL     Bubba Smith  DE  22.0  1976.0    1   2
# 1      1967    1     2  MIN     Clint Jones  RB  22.0  1973.0    0   0
# 2      1967    1     3  SFO  Steve Spurrier  QB  22.0  1976.0    0   0
# 3      1967    1     4  MIA      Bob Griese  QB  22.0  1980.0    2   8
# 4      1967    1     5  HOU  George Webster  LB  21.0  1976.0    3   3
#
#                          ...                           Rec  Rec_Yds  Rec_TD  \
# 0                        ...                           NaN      NaN     NaN
# 1                        ...                          38.0    431.0     0.0
# 2                        ...                           NaN      NaN     NaN
# 3                        ...                           NaN      NaN     NaN
# 4                        ...                           NaN      NaN     NaN
#
#    Tkl  Def_Int  Sk       College    Unnamed: 29          Player_NFL_Link  \
# 0  NaN      NaN NaN  Michigan St.  College Stats  /players/S/SmitBu00.htm
# 1  NaN      NaN NaN  Michigan St.  College Stats  /players/J/JoneCl00.htm
# 2  NaN      NaN NaN       Florida  College Stats  /players/S/SpurSt00.htm
# 3  NaN      NaN NaN        Purdue  College Stats  /players/G/GrieBo00.htm
# 4  NaN      5.0 NaN  Michigan St.  College Stats  /players/W/WebsGe00.htm
#
#                                     Player_NCAA_Link
# 0  http://www.sports-reference.com/cfb/players/bu...
# 1  http://www.sports-reference.com/cfb/players/cl...
# 2  http://www.sports-reference.com/cfb/players/st...
# 3  http://www.sports-reference.com/cfb/players/bo...
# 4  http://www.sports-reference.com/cfb/players/ge...
#
# [5 rows x 32 columns]

# %%
# Clean the data to be filled
draft_df = draft_df.fillna(0)
draft_df.head()
# Out:
#    Draft_Yr  Rnd  Pick   Tm          Player Pos   Age      To  AP1  PB  \
# 0      1967    1     1  BAL     Bubba Smith  DE  22.0  1976.0    1   2
# 1      1967    1     2  MIN     Clint Jones  RB  22.0  1973.0    0   0
# 2      1967    1     3  SFO  Steve Spurrier  QB  22.0  1976.0    0   0
# 3      1967    1     4  MIA      Bob Griese  QB  22.0  1980.0    2   8
# 4      1967    1     5  HOU  George Webster  LB  21.0  1976.0    3   3
#
#                          ...                           Rec  Rec_Yds  Rec_TD  \
# 0                        ...                           0.0      0.0     0.0
# 1                        ...                          38.0    431.0     0.0
# 2                        ...                           0.0      0.0     0.0
# 3                        ...                           0.0      0.0     0.0
# 4                        ...                           0.0      0.0     0.0
#
#    Tkl  Def_Int   Sk       College    Unnamed: 29          Player_NFL_Link  \
# 0  0.0      0.0  0.0  Michigan St.  College Stats  /players/S/SmitBu00.htm
# 1  0.0      0.0  0.0  Michigan St.  College Stats  /players/J/JoneCl00.htm
# 2  0.0      0.0  0.0       Florida  College Stats  /players/S/SpurSt00.htm
# 3  0.0      0.0  0.0        Purdue  College Stats  /players/G/GrieBo00.htm
# 4  0.0      5.0  0.0  Michigan St.  College Stats  /players/W/WebsGe00.htm
#
#                                     Player_NCAA_Link
# 0  http://www.sports-reference.com/cfb/players/bu...
# 1  http://www.sports-reference.com/cfb/players/cl...
# 2  http://www.sports-reference.com/cfb/players/st...
# 3  http://www.sports-reference.com/cfb/players/bo...
# 4  http://www.sports-reference.com/cfb/players/ge...
#
# [5 rows x 32 columns]

# %%
kmf = KaplanMeierFitter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-631ebf3f521d> in <module>()
# ----> 1 kmf = KaplanMeierFitter()
#
# NameError: name 'KaplanMeierFitter' is not defined
